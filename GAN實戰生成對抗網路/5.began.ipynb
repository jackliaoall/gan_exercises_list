# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/carpedm20/BEGAN-tensorflow.git
# %cd BEGAN-tensorflow
# Out:
# Cloning into 'BEGAN-tensorflow'...
# remote: Enumerating objects: 199, done.
# remote: Total 199 (delta 0), reused 0 (delta 0), pack-reused 199
# Receiving objects: 100% (199/199), 23.51 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# /content/BEGAN-tensorflow

# %%
# Download celebA dataset
# !python download.py
# Out:
# [*] ./data/img_align_celeba.zip already exists
# Traceback (most recent call last):
#   File "download.py", line 115, in <module>
#     download_celeb_a(base_path)
#   File "download.py", line 64, in download_celeb_a
#     with zipfile.ZipFile(save_path) as zf:
#   File "/usr/lib/python3.7/zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "/usr/lib/python3.7/zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file

# %%
# Training
# !python main.py --dataset=CelebA --use_gpu=True
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:13: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2022-03-09 13:40:06,081:WARNING::From main.py:13: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Traceback (most recent call last):
#   File "main.py", line 43, in <module>
#     main(config)
#   File "main.py", line 30, in main
#     config.data_format, config.split)
#   File "/content/BEGAN-tensorflow/data_loader.py", line 22, in get_loader
#     with Image.open(paths[0]) as img:
# IndexError: list index out of range
