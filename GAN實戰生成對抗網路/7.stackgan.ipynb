# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/Kuntal-G/StackGAN.git
# %cd StackGAN
# Out:
# fatal: destination path 'StackGAN' already exists and is not an empty directory.
# /content/StackGAN

# %%
# Install using pip
# !pip install prettytensor progressbar python-dateutil easydict pandas torchfile requests
# Out:
# Requirement already satisfied: prettytensor in /usr/local/lib/python3.7/dist-packages (0.7.4)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.7/dist-packages (2.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (2.8.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (1.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.7/dist-packages (0.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: enum34>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from prettytensor) (1.1.10)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from prettytensor) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
# !python google-drive-download.py 0B3y_msrWZaXLT1BZdVdycDY5TEE Data/ birds.zip
# !unzip Data/birds.zip
# Out:
#   File "google-drive-download.py", line 42
#     print " Starting Download"
#                              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(" Starting Download")?
# unzip:  cannot find or open Data/birds.zip, Data/birds.zip.zip or Data/birds.zip.ZIP.

# %%
# !wget http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz -O Data/birds/CUB_200_2011.tgz
# !tar -xzf CUB_200_2011.tgz
# Out:
# Data/birds/CUB_200_2011.tgz: No such file or directory
# tar (child): CUB_200_2011.tgz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !python misc/preprocess_birds.py
# !python google-drive-download.py 0B3y_msrWZaXLNUNKa3BaRjAyTzQ models/ birds_model_164000.ckpt
# !python google-drive-download.py 0B0ywwgffWnLLU0F3UHA3NzFTNEE models/text_encoder/  lm_sje_nc4_cub_hybrid_gru18_a1_c512_0.00070_1_10_trainvalids.txt_iter30000.t7
# Out:
# Traceback (most recent call last):
#   File "misc/preprocess_birds.py", line 10, in <module>
#     from misc.utils import get_image
# ModuleNotFoundError: No module named 'misc'
#   File "google-drive-download.py", line 42
#     print " Starting Download"
#                              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(" Starting Download")?
#   File "google-drive-download.py", line 42
#     print " Starting Download"
#                              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(" Starting Download")?

# %%
# add following lines in the example_captions.txt file
A white bird with a black crown and red beak
this bird has red breast and yellow belly
# Demo run
sh demo/birds_demo.sh
# Out:
#   File "<ipython-input-7-b71e50724cfc>", line 2
#     A white bird with a black crown and red beak
#           ^
# SyntaxError: invalid syntax
