# %%
# %tensorflow_version 1.x
# !git clone https://github.com/jacobgil/keras-dcgan.git
# Out:
# TensorFlow 1.x selected.
# Cloning into 'keras-dcgan'...
# remote: Enumerating objects: 57, done.
# remote: Total 57 (delta 0), reused 0 (delta 0), pack-reused 57
# Unpacking objects: 100% (57/57), done.

# %%
# !python ./keras-dcgan/dcgan.py --mode train  --batch_size 128
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# batch 184 d_loss : 0.289742
# batch 184 g_loss : 1.995031
# batch 185 d_loss : 0.304755
# batch 185 g_loss : 1.822330
# batch 186 d_loss : 0.316996
# batch 186 g_loss : 1.779214
# batch 187 d_loss : 0.384372
# batch 187 g_loss : 1.600751
# batch 188 d_loss : 0.419606
# batch 188 g_loss : 1.856285
# batch 189 d_loss : 0.405001
# batch 189 g_loss : 1.932533
# batch 190 d_loss : 0.415856
# batch 190 g_loss : 1.890303
# batch 191 d_loss : 0.376651
# batch 191 g_loss : 1.432070
# batch 192 d_loss : 0.463118
# batch 192 g_loss : 1.761688
# batch 193 d_loss : 0.434390
# batch 193 g_loss : 1.507730
# batch 194 d_loss : 0.405822
# batch 194 g_loss : 2.009330
# batch 195 d_loss : 0.370838
# batch 195 g_loss : 1.323843
# batch 196 d_loss : 0.325461
# batch 196 g_loss : 2.038643
# batch 197 d_loss : 0.414217
# batch 197 g_loss : 1.512194
# batch 198 d_loss : 0.385520
# batch 198 g_loss : 1.575997
# batch 199 d_loss : 0.402314
# batch 199 g_loss : 1.518170
# ...

# %%
# !python ./keras-dcgan/dcgan.py --mode generate --batch_size 128 --nice
# Out:
# Using TensorFlow backend.
# ./keras-dcgan/dcgan.py:19: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   model.add(Dense(input_dim=100, output_dim=1024))
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Traceback (most recent call last):
#   File "./keras-dcgan/dcgan.py", line 162, in <module>
#     generate(BATCH_SIZE=args.batch_size, nice=args.nice)
#   File "./keras-dcgan/dcgan.py", line 121, in generate
#     g.load_weights('generator')
#   File "/tensorflow-1.15.2/python3.7/keras/engine/saving.py", line 492, in load_wrapper
#     return load_function(*args, **kwargs)
# ...
